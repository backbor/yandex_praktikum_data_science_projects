# %% [markdown]
# ##  Описание проекта
# Компания предоставила данные с характеристиками сотрудников компании. Среди них — уровень удовлетворённости сотрудника работой в компании. Эту информацию получили из форм обратной связи: сотрудники заполняют тест-опросник, и по его результатам рассчитывается доля их удовлетворённости от 0 до 1, где 0 — совершенно неудовлетворён, 1 — полностью удовлетворён.
# Собирать данные такими опросниками не так легко: компания большая, и всех сотрудников надо сначала оповестить об опросе, а затем проследить, что все его прошли.
# У вас будет несколько задач. Первая — построить модель, которая сможет предсказать уровень удовлетворённости сотрудника на основе данных заказчика.
# Почему бизнесу это важно: удовлетворённость работой напрямую влияет на отток сотрудников. А предсказание оттока — одна из важнейших задач HR-аналитиков. Внезапные увольнения несут в себе риски для компании, особенно если уходит важный сотрудник.
# Ваша вторая задача — построить модель, которая сможет на основе данных заказчика предсказать то, что сотрудник уволится из компании.
#
#
# ###  Формулирование задачи
# Задача 1: предсказание уровня удовлетворённости сотрудника
#
# Задача 2: предсказание увольнения сотрудника из компании
#
# ### Описание данных
#
# **По задаче №1**
#
# **train_job_satisfaction_rate.csv**(Тренировочная выборка)
# Таблица, которая содержит данные о поведении покупателя на сайте, о коммуникациях с покупателем и его продуктовом поведении.
# - `id` — уникальный идентификатор сотрудника;
# - `dept ` — отдел, в котором работает сотрудник;
# - `level ` — уровень занимаемой должности;
# - `workload ` — уровень загруженности сотрудника;
# - `employment_years ` — длительность работы в компании (в годах);
# - `last_year_promo ` — показывает, было ли повышение за последний год;
# - `last_year_violations ` —  показывает, нарушал ли сотрудник трудовой договор за последний год;
# - `supervisor_evaluation ` — оценка качества работы сотрудника, которую дал руководитель;
# - `salary ` — ежемесячная зарплата сотрудника;
# - `job_satisfaction_rate ` — уровень удовлетворённости сотрудника работой в компании, целевой признак.
#
# **test_features.csv**(Входные признаки тестовой выборки)
# - `id` — уникальный идентификатор сотрудника;
# - `dept ` — отдел, в котором работает сотрудник;
# - `level ` — уровень занимаемой должности;
# - `workload ` — уровень загруженности сотрудника;
# - `employment_years ` — длительность работы в компании (в годах);
# - `last_year_promo ` — показывает, было ли повышение за последний год;
# - `last_year_violations ` —  показывает, нарушал ли сотрудник трудовой договор за последний год;
# - `supervisor_evaluation ` — оценка качества работы сотрудника, которую дал руководитель;
# - `salary ` — ежемесячная зарплата сотрудника;
#
# **test_target_job_satisfaction_rate.csv** (Целевой признак тестовой выборки).
# Таблица с данными о времени (в минутах), которое покупатель провёл на сайте в течение периода.
# -	`id` —  уникальный идентификатор сотрудника;
# -	`job_satisfaction_rate` — Уровень удовлетворенности чотрудника
# *********************************************************************
# **По задаче №2**
#
# **train_quit.csv**(Тренировочная выборка)
# - `id` — уникальный идентификатор сотрудника;
# - `dept ` — отдел, в котором работает сотрудник;
# - `level ` — уровень занимаемой должности;
# - `workload ` — уровень загруженности сотрудника;
# - `employment_years ` — длительность работы в компании (в годах);
# - `last_year_promo ` — показывает, было ли повышение за последний год;
# - `last_year_violations ` —  показывает, нарушал ли сотрудник трудовой договор за последний год;
# - `supervisor_evaluation ` — оценка качества работы сотрудника, которую дал руководитель;
# - `salary ` — ежемесячная зарплата сотрудника;
# - `quit ` —  целевой признак.
#
# **test_features.csv**(Тестовая выборка )
# - `id` — уникальный идентификатор сотрудника;
# - `dept ` — отдел, в котором работает сотрудник;
# - `level ` — уровень занимаемой должности;
# - `workload ` — уровень загруженности сотрудника;
# - `employment_years ` — длительность работы в компании (в годах);
# - `last_year_promo ` — показывает, было ли повышение за последний год;
# - `last_year_violations ` —  показывает, нарушал ли сотрудник трудовой договор за последний год;
# - `supervisor_evaluation ` — оценка качества работы сотрудника, которую дал руководитель;
# - `salary ` — ежемесячная зарплата сотрудника;
#
# **test_target_quit.csv***(Целевой признак тестовой выборки)
# - `id ` — уникальный идентификатор сотрудника;
# - `quit ` —  целевой признак.
#
#
# План работы:
# **По задаче №1**
# - Шаг 1. Загрузка данных и необходимых иструментов
# - Шаг 2. Предобработка данных
# - Шаг 3. Исследовательский анализ данных
# - Шаг 4. Подготовка данных
# - Шаг 5. Обучение моделей
# - Шаг 6. Оформление выводов
# **По задаче №2**
#
# - Шаг 1. Загрузка данных и необходимых иструментов
# - Шаг 2. Предобработка данных
# - Шаг 3. Исследовательский анализ данных
# - Шаг 4. Добавление нового входного признака
# - Шаг 5. Подготовка данных
# - Шаг 6. Подбор моделей и параметров
# - Шаг 7. Выводы

# %%
#установка необходимых библиотек
# !pip install shap -q
# !pip install phik -q

# %%
#необходимые импорты
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns
import numpy as np
import plotly.express as pe
import os
import time
import math
import sklearn
import warnings #для обработки варнингов
warnings.filterwarnings('ignore')

#Классы для подготовки данных
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import (
                                    OneHotEncoder,
                                    OrdinalEncoder, 
                                    StandardScaler, 
                                    MinMaxScaler,
                                    LabelEncoder
                                    ) 
from sklearn.compose import ColumnTransformer
#Класс для работы с пропусками
from sklearn.impute import SimpleImputer

#Классы моделей 
from sklearn.linear_model import LogisticRegression, LinearRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier, DecisionTreeRegressor
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestRegressor


#Класс Бейсовской оптимизации гиперпараметров.
#from optuna.integration import OptunaSearchCV 
#Классы оптимизации гиперпараметров RandomizedSearchCV и  GridSearchCV
from sklearn.model_selection import RandomizedSearchCV, GridSearchCV

#  класс pipeline
from sklearn.pipeline import Pipeline

#from sklearn.ensemble import RandomForestRegressor

#Классы метрик

from sklearn.metrics import (
                             roc_auc_score,
                             f1_score,
                             precision_score,
                             recall_score,
                             accuracy_score,
                             confusion_matrix,
                             precision_recall_curve,
                             make_scorer
                            )


#from scipy import stats as st
from scipy.stats import pointbiserialr, fisher_exact, chi2_contingency

#from statsmodels.stats.outliers_influence import variance_inflation_factor
# Импорт phik
import phik
from phik import phik_matrix
from phik.report import plot_correlation_matrix

import shap

# %% [markdown]
# ### Загрузка  данных для обоих задач

# %%
try:
    df_t1_train = pd.read_csv('train_job_satisfaction_rate.csv',  sep=',',decimal='.') 
    df_t1_test = pd.read_csv('test_features.csv',  sep=',' )
    df_t1_target_test = pd.read_csv('test_target_job_satisfaction_rate.csv',  sep=',',decimal='.')
    df_t2_train = pd.read_csv('train_quit.csv',  sep=',') 
    df_t2_test = pd.read_csv('test_features.csv',  sep=',') 
    df_t2_target_test = pd.read_csv('test_target_quit.csv',  sep=',') 
except:
    df_t1_train = pd.read_csv('/datasets/train_job_satisfaction_rate.csv',  sep=',',decimal='.') 
    df_t1_test = pd.read_csv('/datasets/test_features.csv',  sep=',' )
    df_t1_target_test = pd.read_csv('/datasets/test_target_job_satisfaction_rate.csv',  sep=',',decimal='.')
    df_t2_train = pd.read_csv('/datasets/train_quit.csv',  sep=',') 
    df_t2_test = pd.read_csv('/datasets/test_features.csv',  sep=',') 
    df_t2_target_test = pd.read_csv('/datasets/test_target_quit.csv',  sep=',')

# %% [markdown]
# ### Задача 1. Обзор данных

# %%
def data_primary_observe (df):
    pd.set_option('display.max_columns', None)
    if df.shape[0] <10:
        df_head = df.head()
    else:
        df_head = df.sample(10, random_state=5)
    display ('Несколько строк датафрейма:', df_head)
    display('*'*50)
    display ('Общая информация по датафрему:')
    df_info = df.info(verbose=None, buf=None, max_cols=None, memory_usage=None, show_counts=None, null_counts=None) #verbose=None, buf=None, max_cols=None, memory_usage=None, show_counts=None, null_counts=None)
    
    print('*'*50)
    #df_describe = df.describe()
    #df_hist = df.hist(figsize=(15, 20));
    #duplicate_quantity = 'Количество явных дубликатов = '+ str(df.duplicated().sum())+'\n' +'*'*50  #проверка наличия явных дубликатов
    #duplicate_quantity =' '.join(['Количество явных дубликатов =', str(df.duplicated().sum()), os.linesep, '*'*50])
    duplicate_quantity = 'Количество явных дубликатов = '+ str(df.duplicated().sum())
    return duplicate_quantity# display (df_head, df_info,  duplicate_quantity)

# %%
data_primary_observe(df_t1_train)
# Out:
# 'Несколько строк датафрейма:'
#           id        dept   level workload  employment_years last_year_promo  \
# 1394  127116       sales  middle      low                 5              no
# 3301  509866  purchasing  junior   medium                 1              no
# 2114  693887       sales  middle   medium                 4              no
# 586   218506  purchasing  middle   medium                 1              no
# 3343  564411       sales  junior   medium                 2              no
# 2663  836882          hr  sinior   medium                 5              no
# 651   529976   marketing  middle   medium                 3              no
# 3743  182573       sales  junior   medium                 2              no
# 412   776621          hr  middle   medium                 4              no
# 3211  492920  technology  junior   medium                 4              no
#
#      last_year_violations  supervisor_evaluation  salary  \
# ...

# %%
data_primary_observe(df_t1_test)
# Out:
# 'Несколько строк датафрейма:'
#           id        dept   level workload  employment_years last_year_promo  \
# 51    314685  technology  junior   medium                 2              no
# 1327  450261  purchasing  junior   medium                 1              no
# 1488  105314          hr  junior      low                 1              no
# 1432  773516       sales  junior   medium                 2              no
# 417   445014   marketing  junior   medium                 2              no
# 269   331483  technology  middle   medium                 6              no
# 191   609865         NaN  junior   medium                 1              no
# 1889  948755  purchasing  junior      low                 2              no
# 1343  892656       sales  middle      low                 4              no
# 1791  425885   marketing  junior      low                 1              no
#
#      last_year_violations  supervisor_evaluation  salary
# ...

# %%
data_primary_observe(df_t1_target_test)
# Out:
# 'Несколько строк датафрейма:'
#           id  job_satisfaction_rate
# 51    431446                   0.63
# 1327  696102                   0.69
# 1488  207434                   0.20
# 1432  380452                   0.70
# 417   363400                   0.32
# 269   327899                   0.24
# 191   343666                   0.53
# 1889  409296                   0.40
# 1343  501580                   0.75
# 1791  369763                   0.58
# '**************************************************'
# 'Общая информация по датафрему:'
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 2 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     2000 non-null   int64
#  1   job_satisfaction_rate  2000 non-null   float64
# dtypes: float64(1), int64(1)
# memory usage: 31.4 KB
# **************************************************
# ...

# %% [markdown]
# Как видим в датасетах  df_t1_test и df_t1_target_test несоответствуют строки, на этапе подготовки данных нужно будет обьединить по id и заново разделить на признаки и таргет.

# %% [markdown]
# ### Подитог: обнаружены пропуски в таблицах  df_t1_train, df_t1_test, колонки dept и level

# %% [markdown]
# ## Задача 1. Предобработка данных

# %%
# в завершении проверим на наличие пробелыов и прочих артефактов
cat_col = df_t1_train.select_dtypes(include='object').columns.tolist()
for i in cat_col:
    print(df_t1_train[i].value_counts())
# Out:
# sales         1512
# technology     866
# purchasing     610
# marketing      550
# hr             456
# Name: dept, dtype: int64
# junior    1894
# middle    1744
# sinior     358
# Name: level, dtype: int64
# medium    2066
# low       1200
# high       734
# Name: workload, dtype: int64
# no     3880
# yes     120
# Name: last_year_promo, dtype: int64
# no     3441
# yes     559
# Name: last_year_violations, dtype: int64

# %%
for i in cat_col:
    print(df_t1_test[i].value_counts())
# Out:
# sales         763
# technology    455
# marketing     279
# purchasing    273
# hr            227
#                 1
# Name: dept, dtype: int64
# junior    974
# middle    854
# sinior    171
# Name: level, dtype: int64
# medium    1043
# low        593
# high       363
#              1
# Name: workload, dtype: int64
# no     1937
# yes      63
# Name: last_year_promo, dtype: int64
# no     1738
# yes     262
# Name: last_year_violations, dtype: int64

# %%
#Нашлись пробелы обработаем
backspace_col = ['workload', 'dept']
df_t1_test[backspace_col]=df_t1_test[backspace_col].replace(" ",np.nan)

# %%
# Посмотрим на пропуски
display (df_t1_train[df_t1_train.isnull().any(1)])
display (df_t1_test[df_t1_test.isnull().any(1)])
# Out:
#           id   dept   level workload  employment_years last_year_promo  \
# 1209  631073  sales     NaN   medium                 1              no
# 1469  416327  sales     NaN      low                 1              no
# 1526  694746    NaN  junior   medium                 5              no
# 1630  814624    NaN  junior   medium                 3              no
# 1633  475114    NaN  junior     high                 4              no
# 1745  135043  sales     NaN   medium                 1              no
# 2522  998838  sales     NaN   medium                 1              no
# 2781  497243    NaN  junior   medium                 1              no
# 2975  168668    NaN  junior      low                 3              no
# 3866  641150    NaN  junior      low                 3              no
#
#      last_year_violations  supervisor_evaluation  salary  \
# 1209                   no                      4   27600
# 1469                   no                      5   18000
# ...

# %%
#Создадим список колонок с пропусками
nan_list =['dept','level', 'workload']

# %%
#Напишем простой заполнитель пропусков наиболее частотным значением
fill_na_ = Pipeline([

     ('imputer', SimpleImputer(strategy ='most_frequent'))
])
 
preprocessor_fill_na = ColumnTransformer(
    transformers=[
        ('fill_na_', fill_na_, nan_list)
    ])

#приеменим
df_t1_train[nan_list] = preprocessor_fill_na.fit_transform(df_t1_train[nan_list]) 
df_t1_test[nan_list] = preprocessor_fill_na.transform(df_t1_test[nan_list]) 
#проверим
display(df_t1_train[nan_list].isna().sum())
display(df_t1_test[nan_list].isna().sum())
# Out:
# dept        0
# level       0
# workload    0
# dtype: int64
# dept        0
# level       0
# workload    0
# dtype: int64

# %% [markdown]
# ###  Подитог:
# Обнаруженые пустые строки в категориальных признаках обработаны как np.nan. Пропуски в колонках 'dept' и  'level' были заменены пайплайном на наиболее частотные.

# %% [markdown]
# ## Исследовательский анализ данных

# %%
#ф-ия обзора вещественных признаков
def hist_with_stat_lines(df, df_col, dtitle, dxlabel, dylabel, bins = 0, kde=False):
    df_col_description =  df_col.describe()
    mean = df_col_description[1]
    std = df_col_description[2]
    df_min = df_col_description[3]
    q1 = df_col_description[4]
    median = df_col_description[5]
    q3 = df_col_description[6]
    df_max = df_col_description[7]
    iqr = (q3-q1)+0.1 
    left_border = q1 - iqr*1.5
    # усы обрезаются минимальным и максимальным значением параметра сооветственно
    if left_border < df_min:
        left_border = df_min
    right_border = q3 + iqr*1.5
    if right_border > df_max:
        right_border = df_max
        
    if bins == 0:
        bins = right_border - left_border
        if bins>100:
            bins = 100
        elif bins<1:
            bins = bins*20
        elif bins>1 and bins<5:
            bins = 5
        bins = int(bins)
    else:
        bins = bins
        
    fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(10,5))
    fig.suptitle(dtitle)   
    fig = sns.histplot(df, x=df_col, bins=bins, kde=kde, ax=axes[0]  ) # binwidth = bins/10 #kde=True  edgecolor='g' bins=bins  binwidth = bins/50
    axes[0].set_title('Гистограмма распределения')
    fig.set(xlim=(left_border, right_border)) 
    ax = sns.boxplot(x=df_col, data=df, ax=axes[1])
    ax = sns.stripplot(x=df_col, data=df, color="orange", jitter=0.2, size=2.5, ax=axes[1])
    axes[1].set_title('"Ящик с усами +"')
    #plt.title(dtitle)
    #plt.xlabel(dxlabel)
    axes[0].set_ylabel(dylabel)
    axes[0].set_xlabel(dxlabel)
    axes[1].set_xlabel(dxlabel)
    #axes[0].set.
    #plt.ylabel(dylabel)
    #fig.supxlabel(dxlabel)
    axes[0].axvline(x=mean,linewidth=1, color='r', linestyle='-' , label= 'mean_value')
    axes[0].axvline(x=median,linewidth=1, color='b', linestyle='-', label= 'median_value')
    axes[0].axvline(x=q1,linewidth=1, color='g', linestyle='--',label= 'Q1_value')
    axes[0].axvline(x=q3,linewidth=1, color='g', linestyle='--',label= 'Q3_value')
    #plt.legend(loc = 'best')
    axes[0].legend(loc = 'best')
    #fig.suptitle(dtitle, fontsize = 13) ;
    return print ('Статистические параметры колонки данных' ,dxlabel,'\n' ,'\n',  df_col_description,'\n')# df_col_description

# %%
hist_with_stat_lines(df_t1_train, df_t1_train['employment_years'], 
                     'Анализ данных в employment_years(стаж работы) датасета df_t1_train', 
                     'К-во лет',
                     'Количество записей',0,True)
# Out:
# Статистические параметры колонки данных К-во лет
#
#  count    4000.000000
# mean        3.718500
# std         2.542513
# min         1.000000
# 25%         2.000000
# 50%         3.000000
# 75%         6.000000
# max        10.000000
# Name: employment_years, dtype: float64

# %%
hist_with_stat_lines(df_t1_test, df_t1_test['employment_years'], 
                     'Анализ данных в employment_years(стаж работы) датасета df_t1_test', 
                     'К-во лет',
                     'Количество записей',0,True)
# Out:
# Статистические параметры колонки данных К-во лет
#
#  count    2000.000000
# mean        3.666500
# std         2.537222
# min         1.000000
# 25%         1.000000
# 50%         3.000000
# 75%         6.000000
# max        10.000000
# Name: employment_years, dtype: float64

# %% [markdown]
# Данные о стаже работы адекватные замечаний нет.

# %%
hist_with_stat_lines(df_t1_train, df_t1_train['supervisor_evaluation'], 
                     'Анализ данных в supervisor_evaluation(оценка рук-ля) датасета df_t1_train', 
                     'Оценка',
                     'Количество записей',0,True)
# Out:
# Статистические параметры колонки данных Оценка
#
#  count    4000.000000
# mean        3.476500
# std         1.008812
# min         1.000000
# 25%         3.000000
# 50%         4.000000
# 75%         4.000000
# max         5.000000
# Name: supervisor_evaluation, dtype: float64

# %%
hist_with_stat_lines(df_t1_train, df_t1_test['supervisor_evaluation'], 
                     'Анализ данных в supervisor_evaluation(оценка рук-ля) датасета df_t1_test', 
                     'Оценка',
                     'Количество записей',0,True)
# Out:
# Статистические параметры колонки данных Оценка
#
#  count    2000.000000
# mean        3.526500
# std         0.996892
# min         1.000000
# 25%         3.000000
# 50%         4.000000
# 75%         4.000000
# max         5.000000
# Name: supervisor_evaluation, dtype: float64

# %% [markdown]
# Данные об оценка руководителя адекватные замечаний нет.

# %%
hist_with_stat_lines(df_t1_train, df_t1_train['salary'], 
                     'Анализ данных в salary(ежемесячная зарплата ) датасета df_t1_train', 
                     'Оценка',
                     'Количество записей',0,True)
# Out:
# Статистические параметры колонки данных Оценка
#
#  count     4000.000000
# mean     33926.700000
# std      14900.703838
# min      12000.000000
# 25%      22800.000000
# 50%      30000.000000
# 75%      43200.000000
# max      98400.000000
# Name: salary, dtype: float64

# %%
hist_with_stat_lines(df_t1_test, df_t1_test['salary'], 
                     'Анализ данных в salary(ежемесячная зарплата ) датасета df_t1_test', 
                     'Оценка',
                     'Количество записей',0,True)
# Out:
# Статистические параметры колонки данных Оценка
#
#  count     2000.000000
# mean     34066.800000
# std      15398.436729
# min      12000.000000
# 25%      22800.000000
# 50%      30000.000000
# 75%      43200.000000
# max      96000.000000
# Name: salary, dtype: float64

# %% [markdown]
# Данные о заработках адекватные замечаний нет.

# %%
hist_with_stat_lines(df_t1_train, df_t1_train['job_satisfaction_rate'], 
                    'Анализ данных в job_satisfaction_rate(уровень удовлетворённости сотрудника работой в компании)\
, целевой признак) датасета df_t1_train', 
                     'Оценка',
                     'Количество записей',0,True)
# Out:
# Статистические параметры колонки данных Оценка
#
#  count    4000.000000
# mean        0.533995
# std         0.225327
# min         0.030000
# 25%         0.360000
# 50%         0.560000
# 75%         0.710000
# max         1.000000
# Name: job_satisfaction_rate, dtype: float64

# %%
hist_with_stat_lines(df_t1_target_test, df_t1_target_test['job_satisfaction_rate'], 
                     'Анализ данных в job_satisfaction_rate(уровень удовлетворённости сотрудника работой в компании)\
, целевой признак) датасета df_t1_target', 
                     'Оценка',
                     'Количество записей',0,True)
# Out:
# Статистические параметры колонки данных Оценка
#
#  count    2000.00000
# mean        0.54878
# std         0.22011
# min         0.03000
# 25%         0.38000
# 50%         0.58000
# 75%         0.72000
# max         1.00000
# Name: job_satisfaction_rate, dtype: float64

# %% [markdown]
# Данные по целевым признакам адекватные замечаний нет.

# %%
df_t1_train.query('salary > 70000')['level'].unique()
# Out:
# array(['sinior'], dtype=object)

# %% [markdown]
# Рассмотрены распределения и статисические параметры колличественных признаков.
# -  `employment_years` — длительность работы в компании (в годах).  Признак колличественный дискретный изменяется в диапазоне 0-10 медиана и среднее 3 и 3.7 соот-но. Выбросы отсутствуют. Форма распределения похожа на распределение Пуассона.
# -  `supervisor_evaluation` - оценка качества работы сотрудника, которую дал руководитель. Признак колличественный дискретный, изменяется в диапазоне 1-5 медиана и среднее 4 и 3.5 соот-но.  Выбросы отсутствуют. Форма распределения близка к смещенному нормальному.
# - `salary` - ежемесячная зарплата сотрудника. Признак колличественный дискретный, изменяется в диапазоне 12000-98400 медиана и среднее 30000 и ~34000 соот-но.  Выбросы отсутствуют, значения свыше q3+1.5iqr являются зарплатами высших должностей. Форма распределения напоминает логнормальное.
# - `job_satisfaction_rate` - уровень удовлетворенности работой. Целевой признак. Признак количетсвенный ближе к непрерывному, изменяется в диапазоне 0.03-1 медиана и среднее  0.56 и 0.53 соот-но. Выбросы отсутствуют. По форме распределения похож на бимодальное.

# %%
#перейдем к анализу корреляций, но id удалим
df_t1_train_=df_t1_train.drop('id' ,  axis=1 )

# %%
num_name_list = df_t1_train_.select_dtypes(include='number').columns.tolist()

# %%
#посмотрим на матрицу корреляций, нет ли мультиколлинеарности

phik_overview = phik_matrix(df_t1_train_, interval_cols=num_name_list)
plot_correlation_matrix(
    phik_overview.values,
    x_labels=phik_overview.columns,
    y_labels=phik_overview.index,
    vmin=0, vmax=1, color_map='Greens',
    title=r'correlation $\phi_K$',
    fontsize_factor=1.5,
    figsize=(20, 15)
)

# %%
#В порядке убывания силы корреляции с целевым "job_satisfaction_rate" признаки расположильсь следующим образом:
corr_rank = phik_overview.iloc[:,8].sort_values(ascending = False )
corr_rank
# Out:
# job_satisfaction_rate    1.000000
# supervisor_evaluation    0.764364
# last_year_violations     0.560348
# employment_years         0.325603
# last_year_promo          0.190803
# salary                   0.165830
# dept                     0.082659
# level                    0.080753
# workload                 0.056128
# Name: job_satisfaction_rate, dtype: float64

# %% [markdown]
# Подитог, мультиколлинеарность во входных признаках отсутствует.

# %% [markdown]
# ## Подготовка данных

# %% [markdown]
# В тренировочном и тестовом датасете равное количество признаков.
# Сначала рассмотрим небинарные категории

# %%
display (df_t1_train['dept'].value_counts())
display (df_t1_train['level'].value_counts())
display (df_t1_train['workload'].value_counts())
# Out:
# sales         1518
# technology     866
# purchasing     610
# marketing      550
# hr             456
# Name: dept, dtype: int64
# junior    1898
# middle    1744
# sinior     358
# Name: level, dtype: int64
# medium    2066
# low       1200
# high       734
# Name: workload, dtype: int64

# %%
#Создадим списки типов данных
t1_cat_name_list =['last_year_promo', 'last_year_violations', 'dept']
t1_ord_name_list = [ 'level', 'workload']
t1_num_name_list = ['employment_years', 'supervisor_evaluation', 'salary' ]

# %%
#Подготовим тренирувочную и тестовую выборки
#т.к порядок строк в датасете df_t1_target_test соответсвует таковому в df_t1_test
#чтобы было однозначно,сначала обьеденим по ID а потом заново разложим на признаки и целевую переменные
df_test_full = pd.merge(df_t1_test, df_t1_target_test, how="left", on="id")
t1_X_train_ = df_t1_train.drop(['job_satisfaction_rate', 'id'] ,  axis=1)
t1_X_test_ = df_test_full.drop(['job_satisfaction_rate', 'id'] ,  axis=1)
t1_y_train_ =  df_t1_train['job_satisfaction_rate']
t1_y_test_ = df_test_full['job_satisfaction_rate']

# %%
#пайплайн подготовки данных 
#Используем OHE кодировщик для бинарных и категорильных признаков- ['dept', 'last_year_promo', 'last_year_violations']
#Ordinal кодировщик для категориальных ранговых [ 'level', 'workload']
#StandardScaler для количественных
RANDOM_STATE = 58
ohe_pipe = Pipeline(
        [
            (
                'simpleImputer_ohe', 
                SimpleImputer(missing_values=np.nan, strategy='most_frequent')
            ),
            (
                'ohe', 
                #OneHotEncoder(drop='first', handle_unknown='ignore')
                OneHotEncoder(drop='first' , sparse=False) # запрещает исмпользовать handle_unknown='ignore' и drop='first' вместе
            )
        ]
    ) 

ord_pipe = Pipeline(
        [
            (
                'simpleImputer_before_ord', 
                SimpleImputer(missing_values=np.nan, strategy='most_frequent')
            ),
            (
                'ord',  
                OrdinalEncoder(
                    categories=[ 
                        #['sales', 'technology', 'purchasing', 'marketing', 'hr'], 
                        ['junior', 'middle', 'sinior'],
                        ['low', 'medium', 'high'],
                    ], 
                    handle_unknown='use_encoded_value', unknown_value=np.nan
                )
            ),
            (
                'simpleImputer_after_ord', 
                SimpleImputer(missing_values=np.nan, strategy='most_frequent')
            )
        ]
    )    

data_preprocessor = ColumnTransformer(
        [
            ('ohe', ohe_pipe, t1_cat_name_list),
            ('ord', ord_pipe, t1_ord_name_list),
            ('num', StandardScaler(), t1_num_name_list)
        ], 
       # remainder='passthrough'
        remainder='drop'
    )
        
    #сделаем доступным снаружи ф-ии pipe_final
    #global pipe_final
pipe_final = Pipeline(
        [
            ('preprocessor', data_preprocessor),
            ('models', LinearRegression() )
        ]
        
    )

# %%
#Порверим работу преобразования данных
data_preprocessor.fit_transform (t1_X_train_)
data_preprocessor.transform (t1_X_test_)
# Out:
# array([[ 0.        ,  0.        ,  1.        , ..., -0.67599051,
#          1.51038061, -0.34410059],
#        [ 0.        ,  0.        ,  0.        , ..., -1.06935129,
#          0.51899196, -0.26355741],
#        [ 0.        ,  0.        ,  0.        , ...,  0.50409185,
#          0.51899196, -0.98844601],
#        ...,
#        [ 0.        ,  0.        ,  0.        , ..., -1.06935129,
#         -0.47239669, -1.31061871],
#        [ 0.        ,  0.        ,  0.        , ...,  1.6841742 ,
#         -2.45517399, -0.10247106],
#        [ 0.        ,  0.        ,  0.        , ..., -1.06935129,
#          0.51899196,  0.30024483]])

# %% [markdown]
# ## Обучение моделей
# Обучите как минимум две модели. Возьмите одну линейную модель, а в качестве второй — дерево решений. Подберите гиперпараметры как минимум для одной модели с помощью одного из известных вам инструментов.
# Выберите лучшую модель и проверьте её качество. Выбор делайте на основе новой метрики — SMAPE (англ. symmetric mean absolute percentage error, «симметричное среднее абсолютное процентное отклонение»).

# %%
#ф-ия расчета smape
def smape(y_true, y_pred):
   # smape_score = 100 * np.mean(np.abs(y_pred - y_true) / ((np.abs(y_pred) + np.abs(y_true))/2))
  #  return smape_score
     return 100 * np.mean(np.abs(y_pred - y_true) / ((np.abs(y_pred) + np.abs(y_true))/2))

# %%
#создадим специальную метрику переключим greater_is_better в False — т.к. мы стремимся минимизировать метрику smape
smape_score = make_scorer(smape, greater_is_better=False)

# %%
#создадим сетку пераметров для подбора моделей.
# В качестве моделей будут использованы DecisionTreeRegressor и LinearRegression
RANDOM_STATE = 58
parameters = [
    # словарь для модели DecisionTreeClassifier()
    {
        'models': [DecisionTreeRegressor(random_state=RANDOM_STATE)],
        #'models__max_depth' : range (1,5),
        #'models__max_depth' : [3,4,5,6,7],
        #'models__max_depth' : [6,7,8,9],
         'models__max_depth' : [8,9,10],
       # 'models__min_samples_leaf':range (1,5),
        'models__min_samples_leaf':range (1,5),
        #'models__min_samples_split': range (1,5),
        #'models__min_samples_split': [3,4,5,6,7],
        'models__min_samples_split': [4,5,6,7],
        #'preprocessor__num': [StandardScaler(), MinMaxScaler(), 'passthrough']  
        'preprocessor__num': [StandardScaler(), MinMaxScaler(), 'drop']  
        
    },
   # best params: {'min_samples_split': 5, 'min_samples_leaf': 5, 'max_depth': None}
    
 
    # словарь для модели LogisticRegression()
      {
        'models': [LinearRegression(
      
        )],
        #'preprocessor__num': [StandardScaler(), MinMaxScaler(), 'passthrough']  
        'preprocessor__num': [StandardScaler(), MinMaxScaler(), 'drop']              
        
    }
    
]

#'''
#oscv = OptunaSearchCV(
#    pipe_final,
#    parameters,
#    cv=5,
#    n_trials=20,
#    scoring='roc_auc',
#    random_state=RANDOM_STATE
#)
#'''

#randomized_search = RandomizedSearchCV(
grid_search = GridSearchCV(
    pipe_final, 
    parameters, 
    cv=5,
    #scoring='r2',
    #scoring='neg_median_absolute_error',#mae
    scoring=smape_score,
    #random_state=RANDOM_STATE,
    n_jobs=-1
)
grid_search.fit(t1_X_train_, t1_y_train_)

print('Лучшая модель и её параметры:\n\n', grid_search.best_estimator_)
print ('Метрика лучшей модели на тренировочной выборке:', grid_search.best_score_)
# Out:
# Лучшая модель и её параметры:
#
#  Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('ohe',
#                                                   Pipeline(steps=[('simpleImputer_ohe',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('ohe',
#                                                                    OneHotEncoder(drop='first',
#                                                                                  sparse=False))]),
#                                                   ['last_year_promo',
#                                                    'last_year_violations',
#                                                    'dept']),
#                                                  ('ord',
#                                                   Pipeline(steps=[('simpleImputer_before_ord',
# ...

# %% [markdown]
# неполная история подбора параметров для grid_search
#
# ('num', StandardScaler(),
#                                                   ['employment_years',
#                                                    'supervisor_evaluation',
#                                                    'salary'])])),
#                 ('models',
#                  DecisionTreeRegressor(max_depth=7, min_samples_split=4,
#                                        random_state=58))])
# Метрика лучшей модели на тренировочной выборке: -17.33516162326878
#
#    ('num', StandardScaler(),
#                                                   ['employment_years',
#                                                    'supervisor_evaluation',
#                                                    'salary'])])),
#                 ('models',
#                  DecisionTreeRegressor(max_depth=9, min_samples_leaf=3,
#                                        min_samples_split=4, random_state=58))])
# Метрика лучшей модели на тренировочной выборке: -15.847226240649794
#
#
#   ('num', MinMaxScaler(),
#                                                   ['employment_years',
#                                                    'supervisor_evaluation',
#                                                    'salary'])])),
#                 ('models',
#                  DecisionTreeRegressor(max_depth=10, min_samples_leaf=3,
#                                        min_samples_split=4, random_state=58))])
# Метрика лучшей модели на тренировочной выборке: -15.28112258800814

# %%
grid_search.best_params_
# Out:
# {'models': DecisionTreeRegressor(max_depth=10, min_samples_leaf=3, min_samples_split=4,
#                        random_state=58),
#  'models__max_depth': 10,
#  'models__min_samples_leaf': 3,
#  'models__min_samples_split': 4,
#  'preprocessor__num': MinMaxScaler()}

# %%
#Рассмотрим итоги работы grid_search
result = pd.DataFrame(grid_search.cv_results_)
pd.set_option('display.max_colwidth', None)
print(result[
    ['rank_test_score', 'param_models', 'mean_test_score','params']
].sort_values('rank_test_score'))
# Out:
#      rank_test_score  \
# 121                1
# 124                1
# 127                1
# 120                4
# 123                4
# ..               ...
# 104              143
# 101              144
# 98               145
# 50               146
# 53               147
#
#                                                                                                              param_models  \
# 121  DecisionTreeRegressor(max_depth=10, min_samples_leaf=3, min_samples_split=4,\n                      random_state=58)
# 124  DecisionTreeRegressor(max_depth=10, min_samples_leaf=3, min_samples_split=4,\n                      random_state=58)
# 127  DecisionTreeRegressor(max_depth=10, min_samples_leaf=3, min_samples_split=4,\n                      random_state=58)
# 120  DecisionTreeRegressor(max_depth=10, min_samples_leaf=3, min_samples_split=4,\n                      random_state=58)
# ...

# %%
#рассчитаем метрику на тесте
y_pred = grid_search.best_estimator_.predict(t1_X_test_)
print ("SMAPE на тесте:",  smape(t1_y_test_, y_pred))
# Out:
# SMAPE на тесте: 14.563026165666454

# %% [markdown]
# ## Итог по подбору  моделей и параметров.
# Установлено, что для данной задачи предсказания уровня удовлетворенности
# наилучшим образом, с результатом по метрике SMAPE на тесте = 14.574744206199552 (согласно заданию на тесте должно быть SMAPE<15 ) справилась модель
# DecisionTreeRegressor с параметрами (max_depth=10, min_samples_leaf=3, min_samples_split=4,
#                        random_state=58), и скалером MinMaxScaler().
# Модель линейной регресии не показала успеха. Т.к. не обладает сопоставимой гибкостью настройки параметров.

# %% [markdown]
# ## Задача 2

# %% [markdown]
#  Все данные загружены в начале проекта, соответсвенно для второй задачи в датасеты
#     df_t2_train, df_t2_test, df_t2_target_test
#     Приступим к ознакомлению с данными

# %%
data_primary_observe(df_t2_train)
# Out:
# 'Несколько строк датафрейма:'
#           id        dept   level workload  employment_years last_year_promo  \
# 1394  660191  purchasing  junior   medium                 3              no
# 3301  758710  technology  junior      low                 1              no
# 2114  192910   marketing  junior   medium                 1              no
# 586   849327       sales  junior      low                 2              no
# 3343  746457       sales  junior      low                 2              no
# 2663  199614          hr  junior   medium                 2              no
# 651   496018  technology  junior   medium                 2              no
# 3743  569604  technology  middle      low                 6              no
# 412   842713       sales  middle   medium                 7              no
# 3211  323418       sales  junior      low                 2              no
#
#      last_year_violations  supervisor_evaluation  salary quit
# ...

# %%
data_primary_observe(df_t2_test)
# Out:
# 'Несколько строк датафрейма:'
#           id        dept   level workload  employment_years last_year_promo  \
# 51    314685  technology  junior   medium                 2              no
# 1327  450261  purchasing  junior   medium                 1              no
# 1488  105314          hr  junior      low                 1              no
# 1432  773516       sales  junior   medium                 2              no
# 417   445014   marketing  junior   medium                 2              no
# 269   331483  technology  middle   medium                 6              no
# 191   609865         NaN  junior   medium                 1              no
# 1889  948755  purchasing  junior      low                 2              no
# 1343  892656       sales  middle      low                 4              no
# 1791  425885   marketing  junior      low                 1              no
#
#      last_year_violations  supervisor_evaluation  salary
# ...

# %%
data_primary_observe(df_t2_target_test)
# Out:
# 'Несколько строк датафрейма:'
#           id quit
# 51    264127   no
# 1327  303402  yes
# 1488  110182  yes
# 1432  676389   no
# 417   569502   no
# 269   488424   no
# 191   783958  yes
# 1889  242927   no
# 1343  381809   no
# 1791  160730   no
# '**************************************************'
# 'Общая информация по датафрему:'
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      2000 non-null   int64
#  1   quit    2000 non-null   object
# dtypes: int64(1), object(1)
# memory usage: 31.4+ KB
# **************************************************
# 'Количество явных дубликатов = 0'

# %% [markdown]
# ### Подитог
# картина похожая, есть пропуски в df_t2_test в колонках  dept,  level
# датасеты df_t2_test и df_t2_target_test имеют не соответсвенный порядок строк и требуют процедуры объединения по id c последующим переразделением на признаки и таргет.

# %% [markdown]
# ## Предобрабтка

# %%
display (df_t2_test[df_t2_test.isnull().any(1)])
# Out:
#           id   dept   level workload  employment_years last_year_promo  \
# 191   609865    NaN  junior   medium                 1              no
# 312   471990  sales     NaN      low                 1              no
# 1196  832342    NaN  junior   medium                 1              no
#
#      last_year_violations  supervisor_evaluation  salary
# 191                    no                      1   20400
# 312                    no                      3   12000
# 1196                   no                      4   28800

# %%
#проверим на наличие пробелов и прочих артефактов
cat_col = df_t2_train.select_dtypes(include='object').columns.tolist()
for i in cat_col:
    print(df_t2_train[i].value_counts())
# Out:
# sales         1438
# technology     928
# purchasing     588
# marketing      582
# hr             464
# Name: dept, dtype: int64
# junior    1949
# middle    1694
# sinior     357
# Name: level, dtype: int64
# medium    2118
# low       1208
# high       674
# Name: workload, dtype: int64
# no     3887
# yes     113
# Name: last_year_promo, dtype: int64
# no     3455
# yes     545
# Name: last_year_violations, dtype: int64
# no     2872
# yes    1128
# Name: quit, dtype: int64

# %%
cat_col = cat_col[:-1]
for i in cat_col:
    print(df_t2_test[i].value_counts())
# Out:
# sales         763
# technology    455
# marketing     279
# purchasing    273
# hr            227
#                 1
# Name: dept, dtype: int64
# junior    974
# middle    854
# sinior    171
# Name: level, dtype: int64
# medium    1043
# low        593
# high       363
#              1
# Name: workload, dtype: int64
# no     1937
# yes      63
# Name: last_year_promo, dtype: int64
# no     1738
# yes     262
# Name: last_year_violations, dtype: int64

# %%
#Нашлись пробелы обработаем
backspace_col = ['workload', 'dept']
df_t2_test[backspace_col]=df_t2_test[backspace_col].replace(" ",np.nan)

# %%
display (df_t2_test[df_t2_test.isnull().any(1)])
# Out:
#           id       dept   level workload  employment_years last_year_promo  \
# 15    590867  marketing  junior      NaN                 4              no
# 191   609865        NaN  junior   medium                 1              no
# 312   471990      sales     NaN      low                 1              no
# 1196  832342        NaN  junior   medium                 1              no
# 1699  822186        NaN  middle   medium                 3              no
#
#      last_year_violations  supervisor_evaluation  salary
# 15                     no                      4   28800
# 191                    no                      1   20400
# 312                    no                      3   12000
# 1196                   no                      4   28800
# 1699                   no                      4   38400

# %%
nan_list = ['dept',  'level', 'workload']

# %%
#приеменим заполнитель из первой задачи
df_t2_test[nan_list] = preprocessor_fill_na.transform(df_t2_test[nan_list]) 
#проверим
display(df_t2_test[nan_list].isna().sum())
# Out:
# dept        0
# level       0
# workload    0
# dtype: int64

# %% [markdown]
# ## Исследовательский анализ

# %%
hist_with_stat_lines(df_t2_train, df_t2_train['employment_years'], 
                     'Анализ данных в employment_years(стаж работы) датасета df_t2_train', 
                     'К-во лет',
                     'Количество записей',0,True)
# Out:
# Статистические параметры колонки данных К-во лет
#
#  count    4000.000000
# mean        3.701500
# std         2.541852
# min         1.000000
# 25%         2.000000
# 50%         3.000000
# 75%         6.000000
# max        10.000000
# Name: employment_years, dtype: float64

# %%
hist_with_stat_lines(df_t2_test, df_t2_test['employment_years'], 
                     'Анализ данных в employment_years(стаж работы) датасета df_t2_test', 
                     'К-во лет',
                     'Количество записей',0,True)
# Out:
# Статистические параметры колонки данных К-во лет
#
#  count    2000.000000
# mean        3.666500
# std         2.537222
# min         1.000000
# 25%         1.000000
# 50%         3.000000
# 75%         6.000000
# max        10.000000
# Name: employment_years, dtype: float64

# %%
hist_with_stat_lines(df_t2_train, df_t2_train['supervisor_evaluation'], 
                     'Анализ данных в supervisor_evaluation(оценка рук-ля) датасета df_t2_train', 
                     'Оценка',
                     'Количество записей',0,True)
# Out:
# Статистические параметры колонки данных Оценка
#
#  count    4000.000000
# mean        3.474750
# std         1.004049
# min         1.000000
# 25%         3.000000
# 50%         4.000000
# 75%         4.000000
# max         5.000000
# Name: supervisor_evaluation, dtype: float64

# %%
hist_with_stat_lines(df_t2_test, df_t2_test['supervisor_evaluation'], 
                     'Анализ данных в supervisor_evaluation(оценка рук-ля) датасета df_t2_test', 
                     'Оценка',
                     'Количество записей',0,True)
# Out:
# Статистические параметры колонки данных Оценка
#
#  count    2000.000000
# mean        3.526500
# std         0.996892
# min         1.000000
# 25%         3.000000
# 50%         4.000000
# 75%         4.000000
# max         5.000000
# Name: supervisor_evaluation, dtype: float64

# %%
hist_with_stat_lines(df_t2_train, df_t2_train['salary'], 
                     'Анализ данных в salary(ежемесячная зарплата ) датасета df_t2_train', 
                     'Заработок',
                     'Количество записей',0,True)
# Out:
# Статистические параметры колонки данных Заработок
#
#  count     4000.000000
# mean     33805.800000
# std      15152.415163
# min      12000.000000
# 25%      22800.000000
# 50%      30000.000000
# 75%      43200.000000
# max      96000.000000
# Name: salary, dtype: float64

# %%
hist_with_stat_lines(df_t2_test, df_t2_test['salary'], 
                     'Анализ данных в salary(ежемесячная зарплата ) датасета df_t2_test', 
                     'Заработок',
                     'Количество записей',0,True)
# Out:
# Статистические параметры колонки данных Заработок
#
#  count     2000.000000
# mean     34066.800000
# std      15398.436729
# min      12000.000000
# 25%      22800.000000
# 50%      30000.000000
# 75%      43200.000000
# max      96000.000000
# Name: salary, dtype: float64

# %%
df_t2_train.query('salary > 75000')['level'].unique()
# Out:
# array(['sinior'], dtype=object)

# %% [markdown]
# ### Подитог по исследовательскому анализу данных.
#
# Рассмотрены распределения и статисические параметры колличественных признаков.
# -  `employment_years` — длительность работы в компании (в годах).  Признак колличественный дискретный изменяется в диапазоне 0-10 медиана и среднее 3 и 3.7 соот-но. Выбросы отсутствуют. Форма распределения похожа на распределение Пуассона.
# -  `supervisor_evaluation` - оценка качества работы сотрудника, которую дал руководитель. Признак колличественный дискретный, изменяется в диапазоне 1-5 медиана и среднее 4 и ~3.5 соот-но.  Выбросы отсутствуют. Форма распределения близка к смещенному нормальному.
# - `salary` - ежемесячная зарплата сотрудника. Признак колличественный дискретный, изменяется в диапазоне 12000-96000 медиана и среднее 30000 и ~34000 соот-но.  Выбросы отсутствуют, значения свыше q3+1.5iqr являются зарплатами высшихи должностей. Форма распределения напоминает логнормальное.

# %% [markdown]
# ### Составим «портрет уволившегося сотрудника».

# %%
df_t2_train_ = df_t2_train.drop('id' ,  axis=1 )
cat = df_t2_train_.select_dtypes(include='object').columns.tolist()
cat = cat[:-1]
num = df_t2_train_.select_dtypes(include='number').columns.tolist()


for i in num:
    fig, axes = plt.subplots(nrows=1, ncols=1, figsize=(10,5))
    fig = sns.histplot( data=df_t2_train_, x=i, hue = 'quit'  ) 
    #fig.suptitle('Распределение признаков', fontweight ="bold") 
    #ax = sns.histplot( data=df_decreased, x=i, ax=axes[1])

# %%
#Добавим в  рассмотрение категориальные признаки
for i in cat:
    fig, axes = plt.subplots(nrows=1, ncols=1, figsize=(10,5))
    # sns.histplot( data=df_t2_train_, x=i, hue = 'quit'  ) 
    fig =sns.countplot(x = i, data = df_t2_train_, hue = 'quit')

# %% [markdown]
# Параметры уволившегося сотрудника
# - 1 стаж работы 1-3 года
# - 2 оценка руководителя 1-3
# - 3 уровень заработка 18-38 т.р.
# - 4 уровень позиции junior
# - 5 наиболее вероятно из низкой или средней загруженностью рабтой
# - 6 отсутствует повышение за послений год
# - 7 в наличии нарушений контракта у волившихся выраженного отличия нет.

# %%
#Построим визуализации относительной доли увалившихся
df_t2_train_portret = df_t2_train.drop('id' ,  axis=1 )
num_discret = df_t2_train_portret.select_dtypes(include='number').columns.tolist()
num_discret = num_discret[:-1]
cat_portret = df_t2_train_portret.select_dtypes(include='object').columns.tolist()
cat_portret = cat_portret[:-1]
ful_portret =  num_discret + cat_portret
#df  = pd.DataFrame()

for i in ful_portret :
    quit_part = i + '_quit_part'
    quit_part = df_t2_train_portret.query('quit =="yes"')[i].value_counts() / df_t2_train_portret[i].value_counts()
    #df = pd.concat([df, quit_part.to_frame()],ignore_index=True)
    ax, fig = plt.subplots(1,1, figsize=(13, 6))
    sns.barplot(y=quit_part, x=quit_part.index, palette='Blues_r')
    plt.title(i, fontsize=20)
    plt.box(True)
    plt.xlabel('Значения признака', fontsize=15)
    plt.ylabel('Доля уволившихся', fontsize=15)
    plt.yticks(fontsize=15);

# %% [markdown]
# ### Добавление нового признака
# satisfaction_rate - удовлетворенность работой рассчитанного на снове предсказания лучшей моделью из задачи 1

# %%
#Уберем таргет id , чтобы скормить датасет best_estimator`у из первой задачи.
df_t2_train_ = df_t2_train.drop(['quit', 'id'] ,  axis=1 )

# %%
#Добавим данные по удовлетворенности работой по модели из первой задачи для тестовой и тренировойной выборки
df_t2_train_['satisfaction_rate'] =  grid_search.best_estimator_.predict(df_t2_train_)
df_t2_test_ = df_t2_test.drop('id' ,  axis=1 )
df_t2_test_['satisfaction_rate'] =  grid_search.best_estimator_.predict(df_t2_test_)
#вернем новый признак в датасет df_t2_train для расчета матрицы корреляций и построения следующей визуализации.
df_t2_train['satisfaction_rate'] = df_t2_train_['satisfaction_rate']

# %%
df_t2_train_
# Out:
#             dept   level workload  employment_years last_year_promo  \
# 0          sales  middle     high                 2              no
# 1          sales  junior   medium                 2              no
# 2     purchasing  middle   medium                 5              no
# 3          sales  junior   medium                 2              no
# 4      marketing  junior   medium                 2              no
# ...          ...     ...      ...               ...             ...
# 3995       sales  junior   medium                 4              no
# 3996       sales  middle     high                 9              no
# 3997  purchasing  junior      low                 2              no
# 3998  purchasing  middle   medium                 2              no
# 3999       sales  junior   medium                 2              no
#
#      last_year_violations  supervisor_evaluation  salary  satisfaction_rate
# ...

# %%
#Сравнение распределения признака job_satisfaction_rate для ушедших и оставшихся работников
sns.displot(data=df_t2_train, x="satisfaction_rate", hue="quit", kind="kde");
#sns.displot(data=df_t2_train, x="satisfaction_rate", hue="quit")

# %%
#посчитаем бисериальный коэфф корреляции
pointbiserialr(df_t2_train['quit'].apply(lambda x: 0 if x == 'no' else 1), df_t2_train['satisfaction_rate'])
# Out:
# PointbiserialrResult(correlation=-0.39653584717910595, pvalue=9.628431687241417e-151)

# %% [markdown]
# Статистическая достоверная отрицательная связь между удовлетворенностью работой и желанием уволиться подтверждается.(т.е в данной кодировке бинарного признака желанию не увольняться соответсвуют бОльшие значения удовлетворенности работой)

# %%
# удалим id
df_t2_train_ = df_t2_train.drop('id' ,  axis=1 )
#список количественных признаков
t2_num_list = ['employment_years', 'supervisor_evaluation', 'salary', 'satisfaction_rate']
#построим матрицу корреляций
phik_overview = phik_matrix(df_t2_train_, interval_cols=t2_num_list)
plot_correlation_matrix(
    phik_overview.values,
    x_labels=phik_overview.columns,
    y_labels=phik_overview.index,
    vmin=0, vmax=1, color_map='Greens',
    title=r'correlation $\phi_K$',
    fontsize_factor=1.5,
    figsize=(20, 15)
)

# %% [markdown]
# ### Подитог.
# Мультиколлинеарность не обнаруживается. Корреляция уровня удовлетворенности работой целевого признака подтверждается.

# %% [markdown]
# ## Подготовка данных
# Будет выполняться на созданном ранее пайплайне оличие одно - в список колличественых признаков будет добавлен уровень удовлетворенности работой.

# %%
#Подготовим тренировочную и тестовую выборки
#т.к порядок строк в датасете df_t2_target_test соответсвует таковому в df_t2_test
#чтобы было однозначно,сначала обьеденим по ID а потом заново разложим на признаки и целевую переменные
df_test_full = pd.merge(df_t2_test, df_t2_target_test, how="left", on="id")
df_test_full
# Out:
#           id        dept   level workload  employment_years last_year_promo  \
# 0     485046   marketing  junior   medium                 2              no
# 1     686555          hr  junior   medium                 1              no
# 2     467458       sales  middle      low                 5              no
# 3     418655       sales  middle      low                 6              no
# 4     789145          hr  middle   medium                 5              no
# ...      ...         ...     ...      ...               ...             ...
# 1995  393147   marketing  junior      low                 3              no
# 1996  109582  technology  middle      low                 3              no
# 1997  305653  technology  junior      low                 1              no
# 1998  160233  technology  middle      low                 8              no
# 1999  771859  purchasing  middle   medium                 1              no
#
# ...

# %%
#вернем новый признак в полный тестовый датасет
df_test_full['satisfaction_rate'] = df_t2_test_['satisfaction_rate']

# %%
len(df_t2_test_['satisfaction_rate'])
# Out:
# 2000

# %%
len(df_test_full['satisfaction_rate'])
# Out:
# 2000

# %%
#Удалим из трейна и теста id и тргет
t2_X_train_ = df_t2_train.drop(['quit', 'id'] ,  axis=1)
t2_X_test_ = df_test_full.drop(['quit', 'id'] ,  axis=1)
#отделим таргеты и закоируем вручную, чтобы было одназначно понятно какой класс что значит.
t2_y_train_ =  df_t2_train['quit']
le = LabelEncoder()
t2_y_train_ = le.fit_transform(t2_y_train_)
#t2_y_train_ =  t2_y_train_.apply(lambda x: 0 if x == 'no' else 1)
t2_y_test_ = df_test_full['quit']
t2_y_test_= le.transform(t2_y_test_)
#t2_y_test_ =  t2_y_test_.apply(lambda x: 0 if x == 'no' else 1)

# %%
df_test_full['satisfaction_rate'] = df_t2_test_['satisfaction_rate']

# %%
#доработаем список признаков
t1_cat_name_list =['dept', 'last_year_promo', 'last_year_violations', ]
t1_ord_name_list = [ 'level', 'workload']
t1_num_name_list = ['employment_years', 'supervisor_evaluation', 'salary', 'satisfaction_rate']

# %%
# проверка работы подготовки данных 
data_preprocessor.fit_transform (t2_X_train_)
data_preprocessor.transform (t2_X_test_)
# Out:
# array([[ 0.        ,  0.        ,  1.        , ..., -0.66947743,
#          1.51928904, -0.33040448],
#        [ 0.        ,  0.        ,  0.        , ..., -1.06294051,
#          0.52319722, -0.25119928],
#        [ 0.        ,  0.        ,  0.        , ...,  0.51091181,
#          0.52319722, -0.96404606],
#        ...,
#        [ 0.        ,  0.        ,  0.        , ..., -1.06294051,
#         -0.47289459, -1.28086684],
#        [ 0.        ,  0.        ,  0.        , ...,  1.69130104,
#         -2.46507821, -0.09278889],
#        [ 0.        ,  0.        ,  0.        , ..., -1.06294051,
#          0.52319722,  0.3032371 ]])

# %%
param_grid = [
    # словарь для модели DecisionTreeClassifier()
    {
        'models': [DecisionTreeClassifier(random_state=RANDOM_STATE)],
        #'models__max_depth': range(2, 5),
        #'models__max_features': range(1, 5),
        'models__max_depth' : [7,8,9,10],
        'models__min_samples_leaf':range (1,5),
        'models__min_samples_split': [4,5,6,7],
        
        
        'preprocessor__num': [StandardScaler(), MinMaxScaler(), 'passthrough']  
    },
    
    # словарь для модели KNeighborsClassifier() 
    {
        'models': [KNeighborsClassifier()],
        'models__n_neighbors': range(2, 5),
        'preprocessor__num': [StandardScaler(), MinMaxScaler(), 'passthrough']   
    },

    
    # словарь для модели SVC()
    {
       
        'models': [SVC(
            random_state=RANDOM_STATE,
            probability=True,
            kernel = 'poly'
    
        )],
        
        'models__degree':  range(2, 5),
        'preprocessor__num': [StandardScaler(), MinMaxScaler(), 'passthrough'] 
                    
        
    },
    # словарь для модели LogisticRegression()
      {
        'models': [LogisticRegression(
            random_state=RANDOM_STATE, 
            solver='liblinear', 
            #solver='saga',
            penalty='l1'
        )],
        'models__C':  range(1, 5),
        'preprocessor__num': [StandardScaler(), MinMaxScaler(), 'passthrough']  
                    
        
    }
    
]



#randomized_search = RandomizedSearchCV(
grid_search = GridSearchCV(
    pipe_final, 
    param_grid, 
    cv=5,
    scoring='roc_auc',
    #random_state=RANDOM_STATE,
    n_jobs=-1
)
grid_search.fit(t2_X_train_, t2_y_train_)

print('Лучшая модель и её параметры:\n\n', grid_search.best_estimator_)
print ('Метрика лучшей модели на тренировочной выборке:', grid_search.best_score_)
# Out:
# Лучшая модель и её параметры:
#
#  Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('ohe',
#                                                   Pipeline(steps=[('simpleImputer_ohe',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('ohe',
#                                                                    OneHotEncoder(drop='first',
#                                                                                  sparse=False))]),
#                                                   ['last_year_promo',
#                                                    'last_year_violations',
#                                                    'dept']),
#                                                  ('ord',
#                                                   Pipeline(steps=[('simpleImputer_before_ord',
# ...

# %%
#уточним лучшие параметры
grid_search.best_params_
# Out:
# {'models': DecisionTreeClassifier(max_depth=7, min_samples_leaf=2, min_samples_split=7,
#                         random_state=58),
#  'models__max_depth': 7,
#  'models__min_samples_leaf': 2,
#  'models__min_samples_split': 7,
#  'preprocessor__num': MinMaxScaler()}

# %% [markdown]
# НА трейне лучший результат показала  DecisionTreeClassifier(max_depth=7, min_samples_leaf=2, min_samples_split=7,
#                         random_state=58) и MinMaxScaler()

# %%
#Проверим на тесте.
y_pred = grid_search.predict_proba(t2_X_test_)[:,1]
print ("ROC_AUC на тесте:",  roc_auc_score(t2_y_test_, y_pred))
# Out:
# ROC_AUC на тесте: 0.9201170756040221

# %% [markdown]
# Очень хорошо, результат достигнут метрика превысила задание(Критерий успеха: ROC-AUC ≥0.91)

# %% [markdown]
# <br/>
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
# <b>На доработку🤔:</b>
#
# Нужно написать развернутые выводы по результатам МО в данной главе

# %%
len(pd.DataFrame(grid_search.cv_results_))
# Out:
# 222

# %%
#Разбор результатов работы GridSearch
#pd.set_option('display.max_rows', None)
#pd.DataFrame(grid_search.cv_results_).sort_values("mean_test_score", ascending = False)

# %% [markdown]
# **Выводы по результатам МО**
#
# Для подбора лучшего коссификатора применялся gridSearch c количеством кросс валидации 5 на каждый
#  вариант подбора. В качестве метрики применялась ROC_AUC. Кодировщики категориальных признаком были статичными этапами пайлайна, а скалеры передавались как гиперпараметры всего их было 2 StandardScaler и MinMaxScaler. К анализу было подано 4 модели:
#
# - DecisionTreeClassifier  с подбором гиперпараметров 'models__max_depth' : [7,8,9,10], 'models__min_samples_leaf':range (1,5),      'models__min_samples_split': [4,5,6,7]
# - KNeighborsClassifier с подбором гиперпараметра  'models__n_neighbors': range(2, 5).
# - SVC(random_state=RANDOM_STATE, probability=True, kernel = 'poly'), с подбором гиперпараметра 'models__degree':  range(2, 5)
# - LogisticRegression( random_state=RANDOM_STATE, solver='liblinear', penalty='l1'), с подбором гиперпараметра 'models__C':  range(1, 5).
#
# В итоге было просчитано 222 варианта и определен победитель им стал   DecisionTreeClassifier(max_depth=7, min_samples_leaf=2, min_samples_split=7,  random_state=58), MinMaxScaler() с метрикой на трейне 0.9225
#
# - Лучшая модель SVC(kernel='poly', probability=True, random_state=58), 'models__degree': 3, 'preprocessor__num': -         -   StandardScaler()} заняла 135 место c метрикой  0.9158
# - Лучшая  LogisticRegression(penalty='l1', random_state=58, solver='liblinear'), 'models__C': 3, 'preprocessor__num': StandardScaler()} заняла 180 место c метрикой 0.9111
#
# - Лучшая KNeighborsClassifier(), 'models__n_neighbors': 3, 'preprocessor__num': MinMaxScaler()} заняла 215 место с метрикой 0.8974
#
# В данной задаче с доминированием категориальных признаков модель DecisionTreeClassifier показала превосходство над остальными в виду ее логической сути и множеству параметров для оптимизациии.

# %% [markdown]
# ###  Сравним распределения признаков на основе веротностей увольнения
# Построим распределения признаков на основе предсказанных вероятностей увольнения. Рассмотрим высоковероятные(вероятность увольнения >0.8) и  низко веротятные увольнения (вероятность увольнения >0.2)

# %%
#Посчитаем вероятности калассификации
#redict_proba = grid_search.predict_proba(t2_X_test_)[:,1]
predict_proba = grid_search.predict_proba(t2_X_test_)

# %%
#Добавим вероятность классификации в X_test
prob_only_for_1_class =np.delete(predict_proba,0, axis=1)
t2_X_test_with_prob = t2_X_test_.copy()
t2_X_test_with_prob['вероятность_классификации_уволится'] = prob_only_for_1_class
#Разделим на датасеты сотрудников с высокой вероятностью, что уволится и что с высокой веротяностью не уволится.
t2_X_test_hi_probability_go_out = t2_X_test_with_prob.query('вероятность_классификации_уволится > 0.8')
t2_X_test_hi_probability_stay_in = t2_X_test_with_prob.query('вероятность_классификации_уволится < 0.2')

# %%
print ('Гистограммы для признаков  красным для сотрудников,\
с высокой вероятностью, что уволится, зеленым для сотрудников что с высокой веротяностью не уволится..\
 ')
cat_list =  t2_X_test_.select_dtypes(include='object').columns.tolist()
for i in cat_list:
    fig, axes = plt.subplots(nrows=1, ncols=1, figsize=(10,5))
    fig = sns.histplot( data=t2_X_test_hi_probability_go_out, color = 'red', x=i)
    fig = sns.histplot( data=t2_X_test_hi_probability_stay_in, color = 'green', x=i)
# Out:
# Гистограммы для признаков  красным для сотрудников,с высокой вероятностью, что уволится, зеленым для сотрудников что с высокой веротяностью не уволится..

# %%
print ('Гистограммы для признаков  красным для сотрудников,\
с высокой вероятностью, что уволится, зеленым для сотрудников что с высокой веротяностью не уволится..\
 ')

num_list =  t2_X_test_.select_dtypes(include='number').columns.tolist()
for i in num_list:
    fig, axes = plt.subplots(nrows=1, ncols=1, figsize=(10,5))
    fig = sns.histplot( data=t2_X_test_hi_probability_go_out, color = 'red', x=i)
    fig = sns.histplot( data=t2_X_test_hi_probability_stay_in, color = 'green', x=i)
# Out:
# Гистограммы для признаков  красным для сотрудников,с высокой вероятностью, что уволится, зеленым для сотрудников что с высокой веротяностью не уволится..

# %% [markdown]
# ## Общий вывод
# **Задача 1: предсказание уровня удовлетворённости сотрудника**
# - 1 Исходные данные предстваляли собой датасеты без особых проблем.
# - 2 На этапе предоработки проверены на отсутвие артефаетных значений категориальные признаки, выявлены пропуски данных и пустые строки в категориальных признаках.Данные строки были приведены к значению  np.nan, которые были заменены наиболее частотными  значениями.
# - 3 На этапе исследовательского анализа проверены на неадекватные значения количественные признаки.Построена матрица корредляций  мультиколлинеарности во входных признаках не обнаружено.
# - 4 Подготовка данных проведена с использованием OHE и Ordinal кодировщиков, для маштабирования количественных признаком применялись StandardScaler и MinMaхScaler. процедуры осуществлялись в пайплайне.
# - 5 При помощи поиска по сетке параметров с частием моделей LinearRegression и  DecisionTreeRegressor подобрали модель заданного качества, которая предсказывает уровень удовлетворенности сотрудника работой. Такой моделью стала  DecisionTreeRegressor с параметрами max_depth=10, min_samples_leaf=3, min_samples_split=4, random_state=58), в качестве скалера был отобран MinMaxScaler на тестовой выбрке модель показала качество 14.5630, что удовлетворяет заданию получить метрику <=15.
#
# **Задача 2: предсказание увольнения сотрудника из компании**
# - Работа по даннной задаче в первых этапах шла аналогичным образом. пп 1-4
# - 5 согласно заданию в датасеты были добавленны колонки с данными об удовлетверенности работой предсказанными лучшей моделью из задачи 1. Признак показал корреляцию с целевым данной задачи. И был добавлен входным признаком классификации.
# - 6 Согласно заданию выполнены иссследования по опредеению штрихов к  "портрету уволившегося сотрудника"
# - - 1 стаж работы 1-3 года
# - - 2 оценка руководителя 1-3
# - - 3 уровень заработка 18-38 т.р.
# - - 4 уровень позиции junior
# - - 5 наиболее вероятно из низкой или средней загруженностью рабтой
# - - 6 отсутствует повышение за послений год
# - - 6 в наличии нарушений контракта у волившихся выраженного отличия нет.
# - 7 На этапе подбора моделей были включены модели DecisionTreeClassifier, KNeighborsClassifier, SVC, LogisticRegression. По итогам работы  поиска по сетке параметров лучшей модели победила DecisionTreeClassifier с параметрами (max_depth=7, min_samples_leaf=2, min_samples_split=7, random_state=58),  в качестве скалера был отобран MinMaxScaler, метрика ROC_AUC на трейне 0.9225, на тесте  0.92011. Таким образом критерий успеха: ROC-AUC ≥0.91 достигнут.
#
#
#
# **Вводы для бизнеса по минимизации текучки кадров**.
# Мы увидели, что загруженность работой сильно коррелирует с заработком, а если он в рамках 18-38 т.р. то очеь вероятно, что сотрудник уволится, особенно при том, что его позиция будет junior, стаж 1-3года и не лучшик отношения с начальством(на основе кровня оценок 1-3). Если возможно, догружаете людей, пусть они больше зарабатывают.
# Уровень удовлетворенности работой играет важную роль условно переломное значение 0.6. ниже этого значения вероятность уволится колеблется, а вот если выше, тогда увольнение наименее вероятно.
# Механизмы корпоративного поощрения показывают положительное влияние, вклад каждого по отдельности не велик, но в совокупности положительный эффект должен  накапливаться.
